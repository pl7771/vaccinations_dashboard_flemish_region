# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from datetime import datetime, date
import pandas as pd
import numpy as np
from app.utils import get_db_engine

# %%
from sqlalchemy.sql.schema import CheckConstraint, Column, ForeignKey
# https://docs.sqlalchemy.org/en/14/orm/self_referential.html
from sqlalchemy.orm import relationship, backref, validates, deferred
from sqlalchemy.sql.sqltypes import Date
from sqlalchemy.sql.sqltypes import Integer
from sqlalchemy.sql.sqltypes import String

# %%
from sqlalchemy.orm import declarative_base
Base = declarative_base()
from app.utils import db_session
# https://statbel.fgov.be/sites/default/files/files/opendata/REFNIS%20code/TU_COM_REFNIS.xlsx
zip_url = "https://statbel.fgov.be/sites/default/files/files/opendata/REFNIS%20code/TU_COM_REFNIS.zip"

class NIC_Code(Base):
    __tablename__ = 'nic_codes'
    
    nic = Column(String(5), primary_key=True)
    parent_nic = Column(String(5), ForeignKey('nic_codes.nic'), nullable=True)
    level = Column(Integer, nullable=False)
    text_nl = Column(String(255))
    text_fr = Column(String(255))
    text_de = Column(String(255))
    valid_from = Column(Date, primary_key=True)
    valid_till = Column(Date, nullable=True)
    
    children = relationship("NIC_Code",
        lazy='select',                    
        backref=backref('parent', remote_side=[nic])
    )
    
    __table_args__ = (
        CheckConstraint('length(nic) = 5', name='nic_length'),
    )
    
    def __repr__(self):
        return """
            <NIC_Code(level='%s', nic='%s', name='%s', parent='%s')>
            """ % (
            self.level,
            self.nic,
            self.text_nl,
            self.parent_nic
        )

    @validates('nic')
    def validate_nic(self, key, nic) -> str:
        if len(nic) != 5:
            raise ValueError("'nic' should be 5 characters long..")
        return nic
    
    @classmethod
    def get_all(cls):
        with db_session(echo=False) as session:
            local_nic_codes_all = session.query(NIC_Code).all()
            session.close()
            if (len(local_nic_codes_all)):
                return local_nic_codes_all
        # extract
        df = pd.read_csv(zip_url, delimiter="|")
        # transform
        df['CD_REFNIS'] = df['CD_REFNIS'].apply(lambda x: '{0:0>5}'.format(x))
        return df[df['CD_SUP_REFNIS'].apply(lambda x: x if (len(x) == 5) else None)]
        # df['DT_VLDT_START'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').date())
        # datetime.strptime(first_date,'%d/%m/%Y').date()
        
        df["DT_VLDT_START"] = np.where(
            df['DT_VLDT_START'] == '01/01/1970',
            date.min,
            df['DT_VLDT_START'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').date())
        )
        df["DT_VLDT_END"] = np.where(
            df['DT_VLDT_END'] == '31/12/9999',
            date.max,
            df['DT_VLDT_END'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y').date())
        )
        
        # list(map(lambda x: datetime.datetime.strptime(x,'%b %d, %Y').strftime('%m/%d/%Y'), old_df['oldDate']))
        # list(map(lambda x: datetime.datetime.strptime(x,'%b %d, %Y').strftime('%m/%d/%Y'), old_df['oldDate']))

        # df["DT_VLDT_START"] = np.where(df['DT_VLDT_START'] == '01/01/1970', date.min, datetime.strptime(df['DT_VLDT_START'], '%d/%m/%y'))
        # df["DT_VLDT_END"] = np.where(df['DT_VLDT_END'] == '31/12/9999', date.max, datetime.strptime(df['DT_VLDT_END'], '%d/%m/%y'))
        # date_time_obj = datetime.strptime(date_time_str, '%d/%m/%y %H:%M:%S')

        # df["DT_VLDT_START"] = pd.to_datetime(df['DT_VLDT_START'], errors = 'coerce')
        # df["DT_VLDT_END"] = pd.to_datetime(df['DT_VLDT_END'], errors = 'coerce')
        # print(df)
        
        return df[df["DT_VLDT_END"] == date.max]
        df.rename(columns={
            "LVL_REFNIS": "level",
            "CD_REFNIS": "nic",
            "CD_SUP_REFNIS": "parent_nic",
            "TX_REFNIS_NL": "text_nl",
            "TX_REFNIS_FR": "text_fr",
            "TX_REFNIS_DE": "text_de",
            "DT_VLDT_START": "valid_from",
            "DT_VLDT_END": "valid_till",
        }, inplace=True)
        # load
        # return df
        list = [
            cls(**kwargs) for kwargs in df.to_dict(orient="records")
        ]
        with db_session(echo=False) as session:
            session.bulk_save_objects(list)
            session.commit()
            session.close()
        return list
        with db_session(echo=False) as session:
            return session.query(NIC_Code).all()

        
        return list

# %%
nic_codes_table = NIC_Code.__table__

engine = get_db_engine(echo=False)
nic_codes_table.drop(engine, checkfirst=True)
nic_codes_table.create(engine)

df = NIC_Code.get_all()
df
# Out:
# 0        None
# 1        None
# 2        None
# 3       02000
# 4        None
#         ...
# 2764    93000
# 2765    93000
# 2766    93000
# 2767    93000
# 2768    93000
# Name: CD_SUP_REFNIS, Length: 2769, dtype: object

# %%
df = NIC_Code.get_all()
df
# Out:
# [
#              <NIC_Code(level='1', nic='02000', name='Vlaams Gewest', parent='-')>
#              ,
#
#              <NIC_Code(level='1', nic='03000', name='Waals Gewest', parent='-')>
#              ,
#
#              <NIC_Code(level='1', nic='04000', name='Brussels Hoofdstedelijk Gewest', parent='-')>
#              ,
#
#              <NIC_Code(level='2', nic='10000', name='Provincie Antwerpen', parent='02000')>
#              ,
#
#              <NIC_Code(level='2', nic='20000', name='Provincie Brabant', parent='-')>
#              ,
#
#              <NIC_Code(level='2', nic='20001', name='Provincie Vlaams-Brabant', parent='02000')>
#              ,
#
#              <NIC_Code(level='2', nic='20002', name='Provincie Waals-Brabant', parent='03000')>
#              ,
#
#              <NIC_Code(level='2', nic='30000', name='Provincie West-Vlaanderen', parent='02000')>
#              ,
#
#              <NIC_Code(level='2', nic='40000', name='Provincie Oost-Vlaanderen', parent='02000')>
#              ,
#
#              <NIC_Code(level='2', nic='50000', name='Provincie Henegouwen', parent='03000')>
#              ,
#
#              <NIC_Code(level='2', nic='60000', name='Provincie Luik', parent='03000')>
#              ,
#
#              <NIC_Code(level='2', nic='70000', name='Provincie Limburg', parent='02000')>
#              ,
#
#              <NIC_Code(level='2', nic='80000', name='Provincie Luxemburg', parent='03000')>
#              ,
#
#              <NIC_Code(level='2', nic='90000', name='Provincie Namen', parent='03000')>
#              ,
#
#              <NIC_Code(level='3', nic='11000', name='Arrondissement Antwerpen', parent='10000')>
#              ,
#
#              <NIC_Code(level='3', nic='12000', name='Arrondissement Mechelen', parent='10000')>
#              ,
#
#              <NIC_Code(level='3', nic='13000', name='Arrondissement Turnhout', parent='10000')>
#              ,
#
#              <NIC_Code(level='3', nic='21000', name='Arrondissement Brussel-Hoofdstad', parent='04000')>
#              ,
#
#              <NIC_Code(level='3', nic='23000', name='Arrondissement Halle-Vilvoorde', parent='20001')>
#              ,
#
#              <NIC_Code(level='3', nic='23000', name='Arrondissement Halle-Vilvoorde', parent='20000')>
#              ,
#
#              <NIC_Code(level='3', nic='24000', name='Arrondissement Leuven', parent='20001')>
#              ,
#
#              <NIC_Code(level='3', nic='24000', name='Arrondissement Leuven', parent='20000')>
#              ,
#
#              <NIC_Code(level='3', nic='25000', name='Arrondissement Nijvel', parent='20002')>
#              ,
#
#              <NIC_Code(level='3', nic='25000', name='Arrondissement Nijvel', parent='20000')>
#              ,
#
#              <NIC_Code(level='3', nic='31000', name='Arrondissement Brugge', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='32000', name='Arrondissement Diksmuide', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='33000', name='Arrondissement Ieper', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='34000', name='Arrondissement Kortrijk', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='35000', name='Arrondissement Oostende', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='36000', name='Arrondissement Roeselare', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='37000', name='Arrondissement Tielt', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='38000', name='Arrondissement Veurne', parent='30000')>
#              ,
#
#              <NIC_Code(level='3', nic='41000', name='Arrondissement Aalst', parent='40000')>
#              ,
#
#              <NIC_Code(level='3', nic='42000', name='Arrondissement Dendermonde', parent='40000')>
#              ,
#
#              <NIC_Code(level='3', nic='43000', name='Arrondissement Eeklo', parent='40000')>
#              ,
#
#              <NIC_Code(level='3', nic='44000', name='Arrondissement Gent', parent='40000')>
#              ,
#
#              <NIC_Code(level='3', nic='45000', name='Arrondissement Oudenaarde', parent='40000')>
#              ,
#
#              <NIC_Code(level='3', nic='46000', name='Arrondissement Sint-Niklaas', parent='40000')>
#              ,
#
#              <NIC_Code(level='3', nic='51000', name='Arrondissement Aat', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='52000', name='Arrondissement Charleroi', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='53000', name='Arrondissement Bergen', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='54000', name='Arrondissement Moeskroen', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='55000', name='Arrondissement Zinnik', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='56000', name='Arrondissement Thuin', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='57000', name='Arrondissement Doornik', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='57000', name='Arrondissement Doornik-Moeskroen', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='58000', name='Arrondissement La Louvière', parent='50000')>
#              ,
#
#              <NIC_Code(level='3', nic='61000', name='Arrondissement Hoei', parent='60000')>
#              ,
#
#              <NIC_Code(level='3', nic='62000', name='Arrondissement Luik', parent='60000')>
#              ,
#
#              <NIC_Code(level='3', nic='63000', name='Arrondissement Verviers', parent='60000')>
#              ,
#
#              <NIC_Code(level='3', nic='64000', name='Arrondissement Borgworm', parent='60000')>
#              ,
#
#              <NIC_Code(level='3', nic='71000', name='Arrondissement Hasselt', parent='70000')>
#              ,
#
#              <NIC_Code(level='3', nic='72000', name='Arrondissement Maaseik', parent='70000')>
#              ,
#
#              <NIC_Code(level='3', nic='73000', name='Arrondissement Tongeren', parent='70000')>
#              ,
#
#              <NIC_Code(level='3', nic='81000', name='Arrondissement Aarlen', parent='80000')>
#              ,
#
#              <NIC_Code(level='3', nic='82000', name='Arrondissement Bastenaken', parent='80000')>
#              ,
#
#              <NIC_Code(level='3', nic='83000', name='Arrondissement Marche-en-Famenne', parent='80000')>
#              ,
#
#              <NIC_Code(level='3', nic='84000', name='Arrondissement Neufchâteau', parent='80000')>
#              ,
#
#              <NIC_Code(level='3', nic='85000', name='Arrondissement Virton', parent='80000')>
#              ,
#
#              <NIC_Code(level='3', nic='91000', name='Arrondissement Dinant', parent='90000')>
#              ,
#
#              <NIC_Code(level='3', nic='92000', name='Arrondissement Namen', parent='90000')>
#              ,
#
#              <NIC_Code(level='3', nic='93000', name='Arrondissement Philippeville', parent='90000')>
#              ,
#
#              <NIC_Code(level='4', nic='11001', name='Aartselaar', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11002', name='Antwerpen', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11003', name='Berchem (Antwerpen)', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11004', name='Boechout', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11005', name='Boom', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11006', name='Borgerhout', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11007', name='Borsbeek', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11008', name='Brasschaat', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11009', name='Brecht', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11010', name='Broechem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11011', name='Burcht', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11012', name='Deurne (Antwerpen)', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11013', name='Edegem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11014', name='Ekeren', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11015', name='Emblem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11016', name='Essen', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11017', name='Halle (Antwerpen)', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11018', name='Hemiksem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11019', name='Hoboken', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11020', name='Hoevenen', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11021', name='Hove (Antwerpen)', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11022', name='Kalmthout', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11023', name='Kapellen (Antwerpen)', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11024', name='Kontich', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11025', name='Lint', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11026', name='Loenhout', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11027', name='Massenhoven', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11028', name='Merksem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11029', name='Mortsel', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11030', name='Niel', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11031', name='Oelegem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11032', name='Oostmalle', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11033', name='Pulderbos', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11034', name='Pulle', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11035', name='Ranst', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11036', name='Reet', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11037', name='Rumst', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11038', name='Schelle', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11039', name='Schilde', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11040', name='Schoten', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11041', name=''s Gravenwezel', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11042', name='Sint-Job-in-'t Goor', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11043', name='Sint-Lenaarts', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11044', name='Stabroek', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11045', name='Terhagen', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11046', name='Viersel', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11047', name='Vremde', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11048', name='Waarloos', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11049', name='Westmalle', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11050', name='Wijnegem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11051', name='Wilrijk', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11052', name='Wommelgem', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11053', name='Wuustwezel', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11054', name='Zandhoven', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11055', name='Zoersel', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11056', name='Zwijndrecht', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='11057', name='Malle', parent='11000')>
#              ,
#
#              <NIC_Code(level='4', nic='12001', name='Beerzel', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12002', name='Berlaar', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12003', name='Bevel', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12004', name='Blaasveld', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12005', name='Bonheiden', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12006', name='Booischot', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12007', name='Bornem', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12008', name='Breendonk', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12009', name='Duffel', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12011', name='Hallaar', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12012', name='Heffen', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12013', name='Heindonk', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12014', name='Heist-op-den-Berg', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12015', name='Hingene', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12016', name='Hombeek', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12017', name='Itegem', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12018', name='Kessel', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12019', name='Koningshooikt', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12020', name='Leest', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12021', name='Lier', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12022', name='Liezele', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12023', name='Lippelo', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12024', name='Mariekerke', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12025', name='Mechelen', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12026', name='Nijlen', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12027', name='Onze-Lieve-Vrouw-Waver', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12028', name='Oppuurs', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12029', name='Putte', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12030', name='Puurs', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12031', name='Rijmenam', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12032', name='Ruisbroek (Mechelen)', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12033', name='Schriek', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12034', name='Sint-Amands', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12035', name='Sint-Katelijne-Waver', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12036', name='Tisselt', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12037', name='Walem', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12038', name='Weert', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12039', name='Wiekevorst', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12040', name='Willebroek', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='12041', name='Puurs-Sint-Amands', parent='12000')>
#              ,
#
#              <NIC_Code(level='4', nic='13001', name='Arendonk', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13002', name='Baarle-Hertog', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13003', name='Balen', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13004', name='Beerse', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13005', name='Bouwel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13006', name='Dessel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13007', name='Eindhout', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13008', name='Geel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13009', name='Gierle', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13010', name='Grobbendonk', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13011', name='Herentals', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13012', name='Herenthout', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13013', name='Herselt', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13014', name='Hoogstraten', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13015', name='Houtvenne', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13016', name='Hulshout', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13017', name='Kasterlee', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13018', name='Lichtaart', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13019', name='Lille', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13020', name='Meer', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13021', name='Meerhout', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13022', name='Meerle', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13023', name='Merksplas', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13024', name='Minderhout', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13025', name='Mol', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13026', name='Morkhoven', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13027', name='Noorderwijk', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13028', name='Oevel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13029', name='Olen', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13030', name='Olmen', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13031', name='Oud-Turnhout', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13032', name='Poederlee', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13033', name='Poppel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13034', name='Ramsel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13035', name='Ravels', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13036', name='Retie', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13037', name='Rijkevorsel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13038', name='Tielen', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13039', name='Tongerlo (Turnhout)', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13040', name='Turnhout', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13041', name='Varendonk', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13042', name='Veerle', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13043', name='Vlimmeren', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13044', name='Vorselaar', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13045', name='Vorst (Turnhout)', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13046', name='Vosselaar', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13047', name='Wechelderzande', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13048', name='Weelde', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13049', name='Westerlo', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13050', name='Westmeerbeek', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13051', name='Wortel', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13052', name='Zoerle-Parwijs', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='13053', name='Laakdal', parent='13000')>
#              ,
#
#              <NIC_Code(level='4', nic='21001', name='Anderlecht', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21002', name='Oudergem', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21003', name='Sint-Agatha-Berchem', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21004', name='Brussel', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21005', name='Etterbeek', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21006', name='Evere', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21007', name='Vorst (Brussel-Hoofdstad)', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21008', name='Ganshoren', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21009', name='Elsene', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21010', name='Jette', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21011', name='Koekelberg', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21012', name='Sint-Jans-Molenbeek', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21013', name='Sint-Gillis', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21014', name='Sint-Joost-ten-Node', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21015', name='Schaarbeek', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21016', name='Ukkel', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21017', name='Watermaal-Bosvoorde', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21018', name='Sint-Lambrechts-Woluwe', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='21019', name='Sint-Pieters-Woluwe', parent='21000')>
#              ,
#
#              <NIC_Code(level='4', nic='23001', name='Alsemberg', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23002', name='Asse', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23003', name='Beersel', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23004', name='Beert', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23005', name='Beigem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23006', name='Bekkerzeel', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23007', name='Bellingen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23008', name='Berg (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23009', name='Bever', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23010', name='Bogaarden', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23011', name='Borchtlombeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23012', name='Brussegem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23013', name='Buizingen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23014', name='Buken', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23015', name='Diegem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23016', name='Dilbeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23017', name='Dworp', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23018', name='Elewijt', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23019', name='Elingen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23020', name='Eppegem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23021', name='Essene', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23022', name='Gaasbeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23023', name='Galmaarden', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23024', name='Gooik', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23025', name='Grimbergen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23026', name='Groot-Bijgaarden', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23027', name='Halle (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23028', name='Hamme (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23029', name='Heikruis', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23030', name='Hekelgem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23031', name='Herfelingen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23032', name='Herne', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23033', name='Hoeilaart', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23034', name='Hofstade (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23035', name='Huizingen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23036', name='Humbeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23037', name='Itterbeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23038', name='Kampenhout', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23039', name='Kapelle-op-den-Bos', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23040', name='Kester', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23041', name='Kobbegem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23042', name='Leerbeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23043', name='Lembeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23044', name='Liedekerke', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23045', name='Londerzeel', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23046', name='Lot', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23047', name='Machelen (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23048', name='Malderen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23049', name='Mazenzele', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23050', name='Meise', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23051', name='Melsbroek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23052', name='Merchtem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23053', name='Mollem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23054', name='Muizen (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23055', name='Nederokkerzeel', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23056', name='Nieuwenrode', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23057', name='Nossegem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23058', name='Oetingen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23060', name='Opwijk', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23061', name='Oudenaken', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23062', name='Overijse', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23064', name='Pepingen', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23065', name='Perk', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23066', name='Peutie', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23067', name='Ramsdonk', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23068', name='Relegem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23069', name='Ruisbroek (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23070', name='Schepdaal', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23071', name='Sint-Katherina-Lombeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23072', name='Sint-Kwintens-Lennik', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23073', name='Sint-Laureins-Berchem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23074', name='Sint-Martens-Bodegem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23075', name='Sint-Martens-Lennik', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23076', name='Sint-Pieters-Kapelle (Halle-Vilvoorde)', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23077', name='Sint-Pieters-Leeuw', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23078', name='Sint-Stevens-Woluwe', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23079', name='Sint-Ulriks-Kapelle', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23080', name='Steenhuffel', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23081', name='Steenokkerzeel', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23082', name='Sterrebeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23084', name='Strombeek-Bever', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23085', name='Teralfene', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23086', name='Ternat', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23087', name='Tollembeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23088', name='Vilvoorde', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23089', name='Vlezenbeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23090', name='Vollezele', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23091', name='Wambeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23092', name='Weerde', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23093', name='Wolvertem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23094', name='Zaventem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23095', name='Zellik', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23096', name='Zemst', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23097', name='Roosdaal', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23098', name='Drogenbos', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23099', name='Kraainem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23100', name='Linkebeek', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23101', name='Sint-Genesius-Rode', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23102', name='Wemmel', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23103', name='Wezembeek-Oppem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23104', name='Lennik', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='23105', name='Affligem', parent='23000')>
#              ,
#
#              <NIC_Code(level='4', nic='24001', name='Aarschot', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24002', name='Assent', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24003', name='Attenhoven', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24004', name='Attenrode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24005', name='Averbode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24006', name='Baal', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24007', name='Begijnendijk', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24008', name='Bekkevoort', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24009', name='Bertem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24010', name='Betekom', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24011', name='Bierbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24012', name='Binkom', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24013', name='Blanden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24014', name='Boortmeerbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24015', name='Bost', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24016', name='Boutersem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24017', name='Budingen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24018', name='Bunsbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24019', name='Deurne (Leuven)', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24020', name='Diest', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24021', name='Dormaal', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24022', name='Drieslinter', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24023', name='Duisburg', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24024', name='Eliksem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24025', name='Erps-Kwerps', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24026', name='Everberg', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24027', name='Ezemaal', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24028', name='Geetbets', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24029', name='Gelrode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24030', name='Glabbeek-Zuurbemde', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24031', name='Goetsenhoven', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24032', name='Grazen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24033', name='Haacht', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24034', name='Haasrode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24035', name='Hakendover', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24036', name='Halle-Booienhoven', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24037', name='Helen-Bos', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24038', name='Herent', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24039', name='Hever', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24040', name='Heverlee', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24041', name='Hoegaarden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24042', name='Hoeleden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24043', name='Holsbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24044', name='Houwaart', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24045', name='Huldenberg', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24046', name='Kaggevinne', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24047', name='Kapellen (Leuven)', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24048', name='Keerbergen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24049', name='Kerkom', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24050', name='Kersbeek-Miskom', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24051', name='Kessel-Lo', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24052', name='Korbeek-Dijle', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24053', name='Korbeek-Lo', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24054', name='Kortenaken', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24055', name='Kortenberg', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24056', name='Kortrijk-Dutsel', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24057', name='Kumtich', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24058', name='Laar', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24059', name='Landen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24060', name='Langdorp', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24061', name='Leefdaal', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24062', name='Leuven', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24063', name='Linden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24064', name='Loonbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24065', name='Lovenjoel', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24066', name='Lubbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24067', name='Meensel-Kiezegem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24068', name='Meerbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24070', name='Melkwezer', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24071', name='Messelbroek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24072', name='Molenbeek-Wersbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24073', name='Molenstede', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24074', name='Neerhespen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24075', name='Neerijse', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24076', name='Neerlanden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24077', name='Neerlinter', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24079', name='Neerwinden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24080', name='Nieuwrode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24081', name='Oorbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24082', name='Oplinter', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24084', name='Orsmaal-Gussenhoven', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24085', name='Ottenburg', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24086', name='Oud-Heverlee', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24087', name='Outgaarden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24088', name='Overhespen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24089', name='Overwinden', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24090', name='Pellenberg', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24091', name='Ransberg', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24092', name='Rillaar', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24093', name='Roosbeek (Leuven)', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24094', name='Rotselaar', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24095', name='Rummen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24096', name='Rumsdorp', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24097', name='Schaffen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24098', name='Scherpenheuvel', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24099', name='Sint-Agatha-Rode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24100', name='Sint-Joris-Weert', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24101', name='Sint-Joris-Winge', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24102', name='Sint-Margriete-Houtem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24103', name='Sint-Pieters-Rode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24104', name='Tervuren', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24105', name='Testelt', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24106', name='Tielt (Leuven)', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24107', name='Tienen', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24108', name='Tildonk', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24109', name='Tremelo', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24110', name='Vaalbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24111', name='Veltem-Beisem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24113', name='Vissenaken', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24114', name='Vossem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24115', name='Waanrode', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24118', name='Walshoutem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24119', name='Wange', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24120', name='Webbekom', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24121', name='Werchter', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24122', name='Wespelaar', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24123', name='Wezemaal', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24126', name='Wilsele', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24127', name='Winksele', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24128', name='Wommersom', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24129', name='Zichem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24130', name='Zoutleeuw', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24131', name='Honsem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24132', name='Orsmaal', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24133', name='Linter', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24134', name='Scherpenheuvel-Zichem', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24135', name='Tielt-Winge', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='24137', name='Glabbeek', parent='24000')>
#              ,
#
#              <NIC_Code(level='4', nic='25001', name='Eerken', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25002', name='Autre-Eglise', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25003', name='Baisy-Thy', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25004', name='Baulers', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25005', name='Bevekom', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25006', name='Bierges', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25007', name='Bierk', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25008', name='Biez', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25009', name='Bomal (Nijvel)', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25010', name='Bonlez', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25011', name='Bornival', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25012', name='Bossut-Gottechain', parent='25000')>
#              ,
#
#              <NIC_Code(level='4', nic='25013', name='Bousval', parent='25000')>
#              ,
#
# ...
#              ,
#
#              <NIC_Code(level='4', nic='41004', name='Aspelare', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41005', name='Baardegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41006', name='Bambrugge', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41007', name='Bavegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41008', name='Borsbeke', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41009', name='Burst', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41010', name='Denderhoutem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41011', name='Denderleeuw', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41012', name='Denderwindeke', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41013', name='Elene', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41014', name='Erembodegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41015', name='Erondegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41016', name='Erpe', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41017', name='Erwetegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41018', name='Geraardsbergen', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41019', name='Gijzegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41020', name='Godveerdegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41021', name='Goeferdinge', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41022', name='Grimminge', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41023', name='Grotenberge', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41024', name='Haaltert', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41025', name='Heldergem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41026', name='Herdersem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41027', name='Herzele', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41028', name='Hillegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41029', name='Hofstade (Aalst)', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41030', name='Iddergem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41031', name='Idegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41032', name='Impe', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41033', name='Kerksken', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41034', name='Lede', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41035', name='Leeuwergem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41036', name='Letterhoutem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41037', name='Lieferinge', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41038', name='Meerbeke', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41039', name='Meldert (Aalst)', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41040', name='Mere', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41041', name='Moerbeke (Aalst)', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41042', name='Moorsel', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41043', name='Nederboelare', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41044', name='Nederhasselt', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41045', name='Neigem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41046', name='Nieuwenhove', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41047', name='Nieuwerkerken (Aalst)', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41048', name='Ninove', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41049', name='Okegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41050', name='Onkerzele', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41051', name='Oombergen', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41052', name='Oordegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41053', name='Ophasselt', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41054', name='Ottergem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41055', name='Outer', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41056', name='Overboelare', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41057', name='Pollare', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41058', name='Ressegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41059', name='Schendelbeke', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41060', name='Sint-Antelinks', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41061', name='Sint-Goriks-Oudenhove', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41062', name='Sint-Lievens-Esse', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41063', name='Sint-Lievens-Houtem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41064', name='Sint-Maria-Oudenhove', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41065', name='Smeerebbe-Vloerzegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41066', name='Smetlede', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41067', name='Steenhuize-Wijnhuize', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41068', name='Strijpen', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41069', name='Velzeke-Ruddershove', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41070', name='Viane', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41071', name='Vlekkem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41072', name='Vlierzele', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41073', name='Voorde', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41074', name='Waarbeke', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41075', name='Wanzele', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41076', name='Welle', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41077', name='Woubrechtegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41078', name='Zandbergen', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41079', name='Zarlardinge', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41080', name='Zonnegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41081', name='Zottegem', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='41082', name='Erpe-Mere', parent='41000')>
#              ,
#
#              <NIC_Code(level='4', nic='42001', name='Appels', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42002', name='Baasrode', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42003', name='Berlare', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42004', name='Buggenhout', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42005', name='Denderbelle', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42006', name='Dendermonde', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42007', name='Grembergen', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42008', name='Hamme (Dendermonde)', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42009', name='Kalken', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42010', name='Laarne', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42011', name='Lebbeke', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42012', name='Massemen', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42013', name='Mespelare', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42014', name='Moerzeke', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42016', name='Oudegem', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42017', name='Overmere', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42018', name='Schellebelle', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42019', name='Schoonaarde', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42020', name='Serskamp', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42021', name='Sint-Gillis-bij-Dendermonde', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42022', name='Uitbergen', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42023', name='Waasmunster', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42024', name='Westrem', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42025', name='Wetteren', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42026', name='Wichelen', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42027', name='Wieze', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='42028', name='Zele', parent='42000')>
#              ,
#
#              <NIC_Code(level='4', nic='43001', name='Adegem', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43002', name='Assenede', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43003', name='Bassevelde', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43004', name='Boekhoute', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43005', name='Eeklo', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43006', name='Ertvelde', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43007', name='Kaprijke', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43009', name='Lembeke', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43010', name='Maldegem', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43011', name='Middelburg', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43012', name='Oosteeklo', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43013', name='Sint-Jan-in-Eremo', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43014', name='Sint-Laureins', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43015', name='Sint-Margriete', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43016', name='Waterland-Oudeman', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43017', name='Watervliet', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='43018', name='Zelzate', parent='43000')>
#              ,
#
#              <NIC_Code(level='4', nic='44001', name='Aalter', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44002', name='Afsnee', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44003', name='Asper', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44004', name='Astene', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44005', name='Baaigem', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44006', name='Bachte-Maria-Leerne', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44007', name='Balegem', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44008', name='Beervelde', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44009', name='Bellem', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44010', name='Bottelare', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44011', name='Deinze', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44012', name='De Pinte', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44013', name='Destelbergen', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44015', name='Deurle', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44016', name='Dikkelvenne', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44017', name='Drongen', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44018', name='Eke', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44019', name='Evergem', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44020', name='Gavere', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44021', name='Gent', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44022', name='Gentbrugge', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44023', name='Gijzenzele', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44024', name='Gontrode', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44025', name='Gottem', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44026', name='Grammene', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44027', name='Hansbeke', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44028', name='Heusden (Gent)', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44029', name='Knesselare', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44030', name='Landegem', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44031', name='Landskouter', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44032', name='Ledeberg', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44034', name='Lochristi', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44035', name='Lotenhulle', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44036', name='Lovendegem', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44037', name='Machelen (Gent)', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44038', name='Mariakerke', parent='44000')>
#              ,
#
#              <NIC_Code(level='4', nic='44039', name='Meigem', parent='44000')>
#              ,
#  ...]

# %%
date_str = '09-19-2018'
print(date_str)

print(type(date_str))


date_object = datetime.strptime(date_str, '%m-%d-%Y').date()
print(type(date_object))
print(date_object)

df = NIC_Code.get_all()
df['DT_VLDT_START'].describe()
first_date = df['DT_VLDT_START'][0]
print(first_date)
print(type(first_date))

len(first_date)
datetime.strptime(first_date,'%d/%m/%Y').date()
# df.describe()
# Out:
# 09-19-2018
# <class 'str'>
# <class 'datetime.date'>
# 2018-09-19
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vh/2z356ng15yq3zcc_tlvwjlqw0000gn/T/ipykernel_73583/1545066939.py in <module>
#      10
#      11 df = NIC_Code.get_all()
# ---> 12 df['DT_VLDT_START'].describe()
#      13 first_date = df['DT_VLDT_START'][0]
#      14 print(first_date)
#
# TypeError: list indices must be integers or slices, not str

# %%
df = NIC_Code.get_all()
array = df[df["DT_VLDT_START"] != "01/01/1970"]["DT_VLDT_START"].unique()
list(map(lambda x: datetime.strptime(x.strip(' \t\r\n'),'%d/%m/%y').date(), array))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vh/2z356ng15yq3zcc_tlvwjlqw0000gn/T/ipykernel_73583/4283510783.py in <module>
#       1 df = NIC_Code.get_all()
#       2 array = df[df["DT_VLDT_START"] != "01/01/1970"]["DT_VLDT_START"].unique()
# ----> 3 list(map(lambda x: datetime.strptime(x.strip(' \t\r\n'),'%d/%m/%y').date(), array))
#
# /var/folders/vh/2z356ng15yq3zcc_tlvwjlqw0000gn/T/ipykernel_73583/4283510783.py in <lambda>(x)
#       1 df = NIC_Code.get_all()
#       2 array = df[df["DT_VLDT_START"] != "01/01/1970"]["DT_VLDT_START"].unique()
# ----> 3 list(map(lambda x: datetime.strptime(x.strip(' \t\r\n'),'%d/%m/%y').date(), array))
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/_strptime.py in _strptime(data_string, format)
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
# --> 352         raise ValueError("unconverted data remains: %s" %
#     353                           data_string[found.end():])
#     354
#
# ValueError: unconverted data remains: 95

# %%
df = NIC_Code.get_all()
df["DT_VLDT_START"].apply(lambda x: datetime.strptime(x,'%d/%m/%Y').date())
# df.apply(lambda x: datetime.strptime(x,'%d/%m/%y'), df['DT_VLDT_START'])
# df.apply(lambda x: datetime.strptime(x['DT_VLDT_START'],'%d/%m/%y'), axis=1)
# map(lambda x: datetime.strptime(x,'%d/%m/%y'), df['DT_VLDT_START'])
df
# Out:
#       LVL_REFNIS CD_REFNIS CD_SUP_REFNIS               TX_REFNIS_DE  \
# 0              1     02000             -           Flämische Region
# 1              1     03000             -         Wallonische Region
# 2              1     04000             -  Region Brüssel-Hauptstadt
# 3              2     10000         02000          Provinz Antwerpen
# 4              2     20000             -            Provinz Brabant
# ...          ...       ...           ...                        ...
# 2764           4     93086         93000                    Vodelée
# 2765           4     93087         93000                    Vogenée
# 2766           4     93088         93000                   Walcourt
# 2767           4     93089         93000               Yves-Gomezée
# 2768           4     93090         93000                  Viroinval
#
#                       TX_REFNIS_FR                    TX_REFNIS_NL  \
# 0                  Région flamande                   Vlaams Gewest
# 1                  Région wallonne                    Waals Gewest
# 2     Région de Bruxelles-Capitale  Brussels Hoofdstedelijk Gewest
# 3                Province d'Anvers             Provincie Antwerpen
# 4              Province de Brabant               Provincie Brabant
# ...                            ...                             ...
# 2764                       Vodelée                         Vodelée
# 2765                       Vogenée                         Vogenée
# 2766                      Walcourt                        Walcourt
# 2767                  Yves-Gomezée                    Yves-Gomezée
# 2768                     Viroinval                       Viroinval
#
#      DT_VLDT_START DT_VLDT_END
# 0       01/01/1970  31/12/9999
# 1       01/01/1970  31/12/9999
# 2       01/01/1970  31/12/9999
# 3       01/01/1970  31/12/9999
# 4       01/01/1970  31/12/1994
# ...            ...         ...
# 2764    01/01/1970  31/12/1976
# 2765    01/01/1970  31/12/1976
# 2766    01/01/1970  31/12/9999
# 2767    01/01/1970  31/12/1976
# 2768    01/01/1977  31/12/9999
#
# [2769 rows x 8 columns]

# %%
df = NIC_Code.get_all()
df["DT_VLDT_START"] = np.where(df['DT_VLDT_START'] == '01/01/1970', pd.NaT, df['DT_VLDT_START'])
df["DT_VLDT_END"] = np.where(df['DT_VLDT_END'] == '31/12/9999', pd.NaT, df['DT_VLDT_END'])
df.CD_REFNIS.unique()
# df["DT_VLDT_START"] = pd.to_datetime(df['DT_VLDT_START'])
# df["DT_VLDT_END"] = pd.to_datetime(df['DT_VLDT_END'])
# Out:
# array(['02000', '03000', '04000', ..., '93088', '93089', '93090'],
#       dtype=object)

# %%
df["DT_VLDT_START"] = pd.to_datetime(df['DT_VLDT_START'], errors = 'coerce')
df["DT_VLDT_END"] = pd.to_datetime(df['DT_VLDT_END'], errors = 'coerce')

df
# Out:
#       LVL_REFNIS CD_REFNIS CD_SUP_REFNIS               TX_REFNIS_DE  \
# 0              1     02000             -           Flämische Region
# 1              1     03000             -         Wallonische Region
# 2              1     04000             -  Region Brüssel-Hauptstadt
# 3              2     10000         02000          Provinz Antwerpen
# 4              2     20000             -            Provinz Brabant
# ...          ...       ...           ...                        ...
# 2764           4     93086         93000                    Vodelée
# 2765           4     93087         93000                    Vogenée
# 2766           4     93088         93000                   Walcourt
# 2767           4     93089         93000               Yves-Gomezée
# 2768           4     93090         93000                  Viroinval
#
#                       TX_REFNIS_FR                    TX_REFNIS_NL  \
# 0                  Région flamande                   Vlaams Gewest
# 1                  Région wallonne                    Waals Gewest
# 2     Région de Bruxelles-Capitale  Brussels Hoofdstedelijk Gewest
# 3                Province d'Anvers             Provincie Antwerpen
# 4              Province de Brabant               Provincie Brabant
# ...                            ...                             ...
# 2764                       Vodelée                         Vodelée
# 2765                       Vogenée                         Vogenée
# 2766                      Walcourt                        Walcourt
# 2767                  Yves-Gomezée                    Yves-Gomezée
# 2768                     Viroinval                       Viroinval
#
#      DT_VLDT_START DT_VLDT_END
# 0       1970-01-01         NaT
# 1       1970-01-01         NaT
# 2       1970-01-01         NaT
# 3       1970-01-01         NaT
# 4       1970-01-01  1994-12-31
# ...            ...         ...
# 2764    1970-01-01  1976-12-31
# 2765    1970-01-01  1976-12-31
# 2766    1970-01-01         NaT
# 2767    1970-01-01  1976-12-31
# 2768    1977-01-01         NaT
#
# [2769 rows x 8 columns]

# %%
df = pd.read_csv(zip_url, delimiter="|")
df.head()
df['CD_REFNIS'] = df['CD_REFNIS'].apply(lambda x: '{0:0>5}'.format(x))
df.head()
df[df['DT_VLDT_END'] != "31/12/9999"]
df[df['DT_VLDT_START'] != "01/01/1970"]
# Out:
#       LVL_REFNIS CD_REFNIS CD_SUP_REFNIS                TX_REFNIS_DE  \
# 5              2     20001         02000    Provinz Flämisch-Brabant
# 6              2     20002         03000  Provinz Wallonisch-Brabant
# 18             3     23000         20001      Bezirk Halle-Vilvoorde
# 20             3     24000         20001                Bezirk Löwen
# 22             3     25000         20002             Bezirk Nivelles
# ...          ...       ...           ...                         ...
# 2675           4     92139         92000         Gembloux-sur-Orneau
# 2676           4     92140         92000          Jemeppe-sur-Sambre
# 2677           4     92141         92000                  La Bruyère
# 2678           4     92142         92000                    Gembloux
# 2768           4     93090         93000                   Viroinval
#
#                         TX_REFNIS_FR                    TX_REFNIS_NL  \
# 5        Province du Brabant flamand        Provincie Vlaams-Brabant
# 6         Province du Brabant wallon         Provincie Waals-Brabant
# 18    Arrondissement de Hal-Vilvorde  Arrondissement Halle-Vilvoorde
# 20         Arrondissement de Louvain           Arrondissement Leuven
# 22        Arrondissement de Nivelles           Arrondissement Nijvel
# ...                              ...                             ...
# 2675             Gembloux-sur-Orneau             Gembloux-sur-Orneau
# 2676              Jemeppe-sur-Sambre              Jemeppe-sur-Sambre
# 2677                      La Bruyère                      La Bruyère
# 2678                        Gembloux                        Gembloux
# 2768                       Viroinval                       Viroinval
#
#      DT_VLDT_START DT_VLDT_END
# 5       01/01/1995  31/12/9999
# 6       01/01/1995  31/12/9999
# 18      01/01/1995  31/12/9999
# 20      01/01/1995  31/12/9999
# 22      01/01/1995  31/12/9999
# ...            ...         ...
# 2675    01/01/1977  31/12/1979
# 2676    01/01/1977  31/12/9999
# 2677    01/01/1977  31/12/9999
# 2678    01/01/1980  31/12/9999
# 2768    01/01/1977  31/12/9999
#
# [107 rows x 8 columns]

# %%
df['CD_REFNIS_CASTED'] = df['CD_REFNIS'].apply(lambda x: '{0:0>5}'.format(x))

# %%
df[df["CD_REFNIS"] == 2000]
# Out:
#    LVL_REFNIS  CD_REFNIS CD_SUP_REFNIS      TX_REFNIS_DE     TX_REFNIS_FR  \
# 0           1       2000             -  Flämische Region  Région flamande
#
#     TX_REFNIS_NL DT_VLDT_START DT_VLDT_END  \
# 0  Vlaams Gewest    01/01/1970  31/12/9999
#
#                                                 test CD_REFNIS_CASTED
# 0  \n            <HelloWorld(name='Hello World')>...            02000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2769 entries, 0 to 2768
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LVL_REFNIS        2769 non-null   int64
#  1   CD_REFNIS         2769 non-null   int64
#  2   CD_SUP_REFNIS     2769 non-null   object
#  3   TX_REFNIS_DE      2769 non-null   object
#  4   TX_REFNIS_FR      2769 non-null   object
#  5   TX_REFNIS_NL      2769 non-null   object
#  6   DT_VLDT_START     2769 non-null   object
#  7   DT_VLDT_END       2769 non-null   object
#  8   test              2769 non-null   object
#  9   CD_REFNIS_CASTED  2769 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 216.5+ KB

# %%
df.columns
# Out:
# Index(['LVL_REFNIS', 'CD_REFNIS', 'CD_SUP_REFNIS', 'TX_REFNIS_DE',
#        'TX_REFNIS_FR', 'TX_REFNIS_NL', 'DT_VLDT_START', 'DT_VLDT_END'],
#       dtype='object')

# %%
df.LVL_REFNIS.unique()
# Out:
# array([1, 2, 3, 4])

# %%
df[df["LVL_REFNIS"] == 2]
df[(df["CD_REFNIS"].astype(str).str.startswith("2")) & (df["CD_REFNIS"].astype(str).str.len() == 5)]
# Out:
#      LVL_REFNIS  CD_REFNIS CD_SUP_REFNIS                TX_REFNIS_DE  \
# 4             2      20000             -             Provinz Brabant
# 5             2      20001         02000    Provinz Flämisch-Brabant
# 6             2      20002         03000  Provinz Wallonisch-Brabant
# 17            3      21000         04000   Bezirk Brüssel-Hauptstadt
# 18            3      23000         20001      Bezirk Halle-Vilvoorde
# ..          ...        ...           ...                         ...
# 580           4      25120         25000                  Orp-Jauche
# 581           4      25121         25000  Ottignies-Louvain-la-Neuve
# 582           4      25122         25000                   Ramillies
# 583           4      25123         25000                      Rebecq
# 584           4      25124         25000                     Walhain
#
#                              TX_REFNIS_FR                      TX_REFNIS_NL  \
# 4                     Province de Brabant                 Provincie Brabant
# 5             Province du Brabant flamand          Provincie Vlaams-Brabant
# 6              Province du Brabant wallon           Provincie Waals-Brabant
# 17   Arrondissement de Bruxelles-Capitale  Arrondissement Brussel-Hoofdstad
# 18         Arrondissement de Hal-Vilvorde    Arrondissement Halle-Vilvoorde
# ..                                    ...                               ...
# 580                            Orp-Jauche                        Orp-Jauche
# 581            Ottignies-Louvain-la-Neuve        Ottignies-Louvain-la-Neuve
# 582                             Ramillies                         Ramillies
# 583                                Rebecq                            Rebecq
# 584                               Walhain                           Walhain
#
#     DT_VLDT_START DT_VLDT_END
# 4      01/01/1970  31/12/1994
# 5      01/01/1995  31/12/9999
# 6      01/01/1995  31/12/9999
# 17     01/01/1970  31/12/9999
# 18     01/01/1995  31/12/9999
# ..            ...         ...
# 580    01/01/1977  31/12/9999
# 581    01/01/1977  31/12/9999
# 582    01/01/1977  31/12/9999
# 583    01/01/1977  31/12/9999
# 584    01/01/1977  31/12/9999
#
# [383 rows x 8 columns]

# %%
def get_nic_codes_for_regions(df):
    return df[df["LVL_REFNIS"] == 1]
    return df[(df["CD_REFNIS"].astype(str).str.startswith("2")) & (df["CD_REFNIS"].astype(str).str.len() == 5)]

# %%
def get_nic_codes_for_provinces(df):
    return df[df["LVL_REFNIS"] == 2]
    return df[(df["CD_REFNIS"].astype(str).str.startswith("2")) & (df["CD_REFNIS"].astype(str).str.len() == 5)]

# %%
def get_nic_codes_for_districts(df):
    return df[df["LVL_REFNIS"] == 3]
    return df[(df["CD_REFNIS"].astype(str).str.startswith("2")) & (df["CD_REFNIS"].astype(str).str.len() == 5)]

# %%
get_nic_codes_for_provinces(df)
# Out:
#     LVL_REFNIS  CD_REFNIS CD_SUP_REFNIS                TX_REFNIS_DE  \
# 3            2      10000         02000           Provinz Antwerpen
# 4            2      20000             -             Provinz Brabant
# 5            2      20001         02000    Provinz Flämisch-Brabant
# 6            2      20002         03000  Provinz Wallonisch-Brabant
# 7            2      30000         02000        Provinz Westflandern
# 8            2      40000         02000         Provinz Ostflandern
# 9            2      50000         03000            Provinz Hennegau
# 10           2      60000         03000             Provinz Lüttich
# 11           2      70000         02000             Provinz Limburg
# 12           2      80000         03000           Provinz Luxemburg
# 13           2      90000         03000               Provinz Namur
#
#                        TX_REFNIS_FR               TX_REFNIS_NL DT_VLDT_START  \
# 3                 Province d'Anvers        Provincie Antwerpen    01/01/1970
# 4               Province de Brabant          Provincie Brabant    01/01/1970
# 5       Province du Brabant flamand   Provincie Vlaams-Brabant    01/01/1995
# 6        Province du Brabant wallon    Provincie Waals-Brabant    01/01/1995
# 7   Province de Flandre occidentale  Provincie West-Vlaanderen    01/01/1970
# 8     Province de Flandre orientale  Provincie Oost-Vlaanderen    01/01/1970
# 9               Province du Hainaut       Provincie Henegouwen    01/01/1970
# 10                Province de Liège             Provincie Luik    01/01/1970
# 11             Province du Limbourg          Provincie Limburg    01/01/1970
# 12           Province du Luxembourg        Provincie Luxemburg    01/01/1970
# 13                Province de Namur            Provincie Namen    01/01/1970
#
#    DT_VLDT_END                                               test
# 3   31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 4   31/12/1994  \n            <HelloWorld(name='Hello World')>...
# 5   31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 6   31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 7   31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 8   31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 9   31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 10  31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 11  31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 12  31/12/9999  \n            <HelloWorld(name='Hello World')>...
# 13  31/12/9999  \n            <HelloWorld(name='Hello World')>...

# %%
class HelloWorld():
    def __init__(self):
        self.name = "Hello World"        
    def __repr__(self):
        return """
            <HelloWorld(name='%s')>
        """ % (self.name)

# %%
hello = HelloWorld()
hello
# Out:
#             <HelloWorld(name='Hello World')>

# %%
df['test'] = hello
