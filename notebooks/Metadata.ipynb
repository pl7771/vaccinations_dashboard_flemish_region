# %%
from datetime import date, datetime, timedelta
from pytz import timezone
import pytz
utc = pytz.utc
# utc.zone
brussels = timezone('Europe/Brussels')
# brussels.zone
today = datetime.now(brussels).date()
# date.today()

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from datetime import datetime, date
import pandas as pd
import numpy as np

# %%
from app.utils import get_db_engine

# %%
from app.etl.pipeline import Pipeline
from app.etl.pipeline import Transformer
from app.models import models
from app.models.metadata import ETL_Metadata

# %%
pl = {
  "source": "https://statbel.fgov.be/sites/default/files/files/opendata/deathday/DEMO_DEATH_OPEN.zip",
  "model": "NumberOfDeathsByDistrictNISCode",
  "metadata_handler": {
    "frequency": "daily",
    "date_column": "date"
  },
  "tranforms": [
    {
      "type": "drop_columns",
      "data": {
        "columns": [
          "CD_PROV",
          "CD_REGIO",
          "NR_YEAR",
          "NR_WEEK"
        ]
      }
    },
    {
      "type": "rename_columns",
      "data": {
        "columns": {
          "CD_ARR": "nis_district",
          "CD_SEX": "sex",
          "CD_AGEGROUP": "agegroup",
          "DT_DATE": "date",
          "MS_NUM_DEATH": "number_of_deaths"
        }
      }
    },
    {
      "type": "update_value",
      "data": {
        "column": "date",
        "update": {
          "type": "date",
          "format": "%d/%m/%Y"
        }
      }
    },
    {
      "type": "group_by",
      "data": {
        "columns": [
          "date",
          "nis_district",
          "sex",
          "agegroup"
        ],
        "aggregate": {
          "type": "sum"
        }
      }
    },
    {
      "type": "update_value",
      "data": {
        "column": "nis_district",
        "type": "string",
        "update": {
          "type": "string",
          "format": "{0:0>5}"
        }
      }
    }
  ]
}

# %%
transformer=Transformer(pl["tranforms"])
pipeline = Pipeline(
    data_class=getattr(models, pl["model"]),
    path=pl["source"],
    transformer=transformer
)

# %%
data_frame = pipeline.extract()

# %%
data_frame
# Out:
#         CD_ARR  CD_PROV  CD_REGIO  CD_SEX CD_AGEGROUP     DT_DATE  NR_YEAR  \
# 0        11000    10000      2000       1       45-64    1/1/2009     2009
# 1        11000    10000      2000       1       65-74    1/1/2009     2009
# 2        11000    10000      2000       1       75-84    1/1/2009     2009
# 3        11000    10000      2000       1         85+    1/1/2009     2009
# 4        11000    10000      2000       2       65-74    1/1/2009     2009
# ...        ...      ...       ...     ...         ...         ...      ...
# 769385   21000     4000      4000       2       25-44  31/10/2021     2021
# 769386   21000     4000      4000       2       45-64  31/10/2021     2021
# 769387   21000     4000      4000       2       65-74  31/10/2021     2021
# 769388   21000     4000      4000       2       75-84  31/10/2021     2021
# 769389   21000     4000      4000       2         85+  31/10/2021     2021
#
#          NR_WEEK  MS_NUM_DEATH
# 0       2009-W01             3
# 1       2009-W01             3
# 2       2009-W01             6
# 3       2009-W01             5
# 4       2009-W01             1
# ...          ...           ...
# 769385  2021-W43             2
# 769386  2021-W43             2
# 769387  2021-W43             4
# 769388  2021-W43             4
# 769389  2021-W43             2
#
# [769390 rows x 9 columns]

# %%
data_frame.describe()
# Out:
#               CD_ARR        CD_PROV       CD_REGIO         CD_SEX  \
# count  769390.000000  769390.000000  769390.000000  769390.000000
# mean    45619.111244   41731.346078    2492.861878       1.476951
# std     22528.129442   23609.477451     589.889828       0.499469
# min     11000.000000    4000.000000    2000.000000       1.000000
# 25%     25000.000000   20002.000000    2000.000000       1.000000
# 50%     44000.000000   40000.000000    2000.000000       1.000000
# 75%     62000.000000   60000.000000    3000.000000       2.000000
# max     93000.000000   90000.000000    4000.000000       2.000000
#
#              NR_YEAR   MS_NUM_DEATH
# count  769390.000000  769390.000000
# mean     2014.951742       1.822042
# std         3.705712       1.389211
# min      2009.000000       1.000000
# 25%      2012.000000       1.000000
# 50%      2015.000000       1.000000
# 75%      2018.000000       2.000000
# max      2021.000000      33.000000

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769390 entries, 0 to 769389
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   CD_ARR        769390 non-null  int64
#  1   CD_PROV       769390 non-null  int64
#  2   CD_REGIO      769390 non-null  int64
#  3   CD_SEX        769390 non-null  int64
#  4   CD_AGEGROUP   769390 non-null  object
#  5   DT_DATE       769390 non-null  object
#  6   NR_YEAR       769390 non-null  int64
#  7   NR_WEEK       769390 non-null  object
#  8   MS_NUM_DEATH  769390 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 52.8+ MB

# %%
data_frame.isnull().sum()
# Out:
# CD_ARR          0
# CD_PROV         0
# CD_REGIO        0
# CD_SEX          0
# CD_AGEGROUP     0
# DT_DATE         0
# NR_YEAR         0
# NR_WEEK         0
# MS_NUM_DEATH    0
# dtype: int64

# %%
df = pipeline.transform(data_frame)

# %%
data_frame
# Out:
#         nis_district  sex agegroup        date  number_of_deaths
# 0              11000    1    45-64  2009-01-01                 3
# 1              11000    1    65-74  2009-01-01                 3
# 2              11000    1    75-84  2009-01-01                 6
# 3              11000    1      85+  2009-01-01                 5
# 4              11000    2    65-74  2009-01-01                 1
# ...              ...  ...      ...         ...               ...
# 769385         21000    2    25-44  2021-10-31                 2
# 769386         21000    2    45-64  2021-10-31                 2
# 769387         21000    2    65-74  2021-10-31                 4
# 769388         21000    2    75-84  2021-10-31                 4
# 769389         21000    2      85+  2021-10-31                 2
#
# [769390 rows x 5 columns]

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769390 entries, 0 to 769389
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   nis_district      769390 non-null  int64
#  1   sex               769390 non-null  int64
#  2   agegroup          769390 non-null  object
#  3   date              769390 non-null  object
#  4   number_of_deaths  769390 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 29.4+ MB

# %%
list = [
    pipeline.data_class(**kwargs) for kwargs in data_frame.to_dict(orient="records")
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vh/2z356ng15yq3zcc_tlvwjlqw0000gn/T/ipykernel_6915/553347417.py in <module>
# ----> 1 list = [
#       2     pipeline.data_class(**kwargs) for kwargs in data_frame.to_dict(orient="records")
#       3 ]
#
# /var/folders/vh/2z356ng15yq3zcc_tlvwjlqw0000gn/T/ipykernel_6915/553347417.py in <listcomp>(.0)
#       1 list = [
# ----> 2     pipeline.data_class(**kwargs) for kwargs in data_frame.to_dict(orient="records")
#       3 ]
#
# <string> in __init__(self, **kwargs)
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/orm/state.py in _initialize_instance(*mixed, **kwargs)
#     478         except:
#     479             with util.safe_reraise():
# --> 480                 manager.dispatch.init_failure(self, args, kwargs)
#     481
#     482     def get_history(self, key, passive):
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/orm/state.py in _initialize_instance(*mixed, **kwargs)
#     475
#     476         try:
# --> 477             return manager.original_init(*mixed[1:], **kwargs)
#     478         except:
#     479             with util.safe_reraise():
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/orm/decl_base.py in _declarative_constructor(self, **kwargs)
#    1155                 "%r is an invalid keyword argument for %s" % (k, cls_.__name__)
#    1156             )
# -> 1157         setattr(self, k, kwargs[k])
#    1158
#    1159
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/orm/attributes.py in __set__(self, instance, value)
#     457
#     458     def __set__(self, instance, value):
# --> 459         self.impl.set(
#     460             instance_state(instance), instance_dict(instance), value, None
#     461         )
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/orm/attributes.py in set(self, state, dict_, value, initiator, passive, check_old, pop)
#    1080
#    1081         if self.dispatch.set:
# -> 1082             value = self.fire_replace_event(
#    1083                 state, dict_, value, old, initiator
#    1084             )
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/orm/attributes.py in fire_replace_event(self, state, dict_, value, previous, initiator)
#    1088     def fire_replace_event(self, state, dict_, value, previous, initiator):
#    1089         for fn in self.dispatch.set:
# -> 1090             value = fn(
#    1091                 state, value, previous, initiator or self._replace_token
#    1092             )
#
# ~/.local/share/virtualenvs/DataEngineeringProjectII-bdwPgCe6/lib/python3.8/site-packages/sqlalchemy/orm/util.py in set_(state, value, oldvalue, initiator)
#     183         def set_(state, value, oldvalue, initiator):
#     184             if include_backrefs or not detect_is_backref(state, initiator):
# --> 185                 return validator(state.obj(), key, value)
#     186             else:
#     187                 return value
#
# ~/Projects/HoGent/DataEngineeringProjectII/app/models/models.py in validate_nis_code(self, key, nis_code)
#     258     @validates('nis_code')
#     259     def validate_nis_code(self, key, nis_code) -> str:
# --> 260         if len(nis_code) != 5:
#     261             raise ValueError("'nis_code' should be 5 characters long..")
#     262         return nis_code
#
# TypeError: object of type 'int' has no len()

# %%
list

# %%
data_frame = pipeline.handle_metadata(data_frame)

# %%
data_frame

# %%
data_frame = data_frame.groupby([
    'year', 'nis', 'sex',
    'nationality_code', 'nationality_text_nl', 'nationality_text_fr',
    'marital_status_code',
    'marital_status_text_nl',
    'marital_status_text_fr',
    'age'
]).sum().reset_index()
data_frame

# %%
data_frame.groupby(['year', 'nis', 'sex', 'nationality_code', 'marital_status_code', 'age'])['population'].transform('size')

# %%
data_frame[data_frame.groupby(['year', 'nis', 'sex', 'nationality_code', 'marital_status_code', 'age'])['nis'].transform('size') > 1]

# %%
data_frame = data_frame.groupby([
    'year', 'week', 'nis_district',
    'sex', 'agegroup', 'date'
]).sum().reset_index()
data_frame

# %%
data_frame.dropna(inplace=True)

# %%
data_frame.isnull().sum()

# %%
test = 2021
type(test)

# %%
starting_day_of_current_year = datetime.now().date().replace(month=1, day=1)    
ending_day_of_current_year = datetime.now().date().replace(month=12, day=31)
starting_day_of_current_year

# %%
frequency = "daily"
frequency is not "daily"

# %%
test = "Hello World"
if 'llo W'.lower() in test.lower():
    print('FOUND')
# Out:
# FOUND

# %%
def days_between(d1, d2):
    d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    d3 = d2 + time
    return abs((d2 - d1).days)

days_between("2021-1-1", "2021-1-31")
# Out:
# 30
